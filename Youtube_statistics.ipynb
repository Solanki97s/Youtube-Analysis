# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataa=pd.read_csv(r'C:\Users\252ha\Desktop\DATA ANALYST\dataset\Global YouTube Statistics.csv',encoding='unicode_escape')

# %%
dataa.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
dataa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
dataa.shape
# Out:
# (995, 28)

# %%
null_data=dataa.isnull().sum()

# %%
null_data[null_data>0]
# Out:
# category                                    46
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %%
cat_col=dataa.select_dtypes(include=['object']).columns

dataa[cat_col]=dataa[cat_col].fillna("Unknown")

# %%
num_col=dataa.select_dtypes(include=['int64', 'float']).columns

dataa[num_col]=dataa[num_col].fillna("0")

# %%
dataa.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %%
dataa.describe()
# Out:
#             rank   subscribers   video views        uploads  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254
# min      1.00000  1.230000e+07  0.000000e+00       0.000000
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000
#
#        lowest_monthly_earnings  highest_monthly_earnings  \
# count               995.000000              9.950000e+02
# mean              36886.148281              5.898078e+05
# std               71858.724092              1.148622e+06
# min                   0.000000              0.000000e+00
# 25%                2700.000000              4.350000e+04
# 50%               13300.000000              2.127000e+05
# ...

# %%
pd.set_option('display.max_columns', None)
dataa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 995 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  995 non-null    object
#  8   Abbreviation                             995 non-null    object
#  9   channel_type                             995 non-null    object
# ...

# %%
dataa=dataa.astype({
    'video views':'int64',
    'lowest_monthly_earnings':'int64',
    'highest_monthly_earnings':'int64',  
    'lowest_yearly_earnings':'int64',      
    'highest_yearly_earnings':'int64', 
    'created_year':'int64'   
})
dataa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    int64
#  4   category                                 995 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  995 non-null    object
#  8   Abbreviation                             995 non-null    object
#  9   channel_type                             995 non-null    object
# ...

# %%
channels_in_year= dataa['created_year'].value_counts() 
channels_in_year
# Out:
# created_year
# 2014    98
# 2006    91
# 2011    82
# 2016    77
# 2013    76
# 2015    73
# 2017    68
# 2012    68
# 2009    52
# 2007    49
# 2010    48
# 2008    46
# 2018    46
# 2019    33
# 2020    30
# 2005    24
# 2021    23
# 0        5
# 2022     5
# 1970     1
# Name: count, dtype: int64

# %%
# In order to be able to plot 'channels_in_year' we need it as a dataframe. one solution is:
channels_in_year= pd.DataFrame(channels_in_year) #first make a DataFrame. 
channels_in_year= channels_in_year.reset_index() #reset the index
channels_in_year.columns = ['Year','Created Channels'] #define columns' names
channels_in_year
# Out:
#     Year  Created Channels
# 0   2014                98
# 1   2006                91
# 2   2011                82
# 3   2016                77
# 4   2013                76
# 5   2015                73
# 6   2017                68
# 7   2012                68
# 8   2009                52
# 9   2007                49
# 10  2010                48
# 11  2008                46
# 12  2018                46
# 13  2019                33
# 14  2020                30
# 15  2005                24
# 16  2021                23
# 17     0                 5
# 18  2022                 5
# 19  1970                 1

# %%
channels_in_year=channels_in_year.sort_values(by='Year',ascending=True)
channel_in_year=channels_in_year.drop(axis=0,index=[17, 19])
channels_in_year= channels_in_year.reset_index(drop= True)

channels_in_year
# Out:
#     Year  Created Channels
# 0      0                 5
# 1   1970                 1
# 2   2005                24
# 3   2006                91
# 4   2007                49
# 5   2008                46
# 6   2009                52
# 7   2010                48
# 8   2011                82
# 9   2012                68
# 10  2013                76
# 11  2014                98
# 12  2015                73
# 13  2016                77
# 14  2017                68
# 15  2018                46
# 16  2019                33
# 17  2020                30
# 18  2021                23
# 19  2022                 5

# %%
x=channels_in_year['Year']
y=channels_in_year['Created Channels']

fig=plt.figure(figsize=(10,4))

plt.bar(x,y,color='#32A645')

plt.ylim(0,110)
plt.xlim(2004,2022)

plt.plot(x,y)

# %%
channel_type=dataa['category'].value_counts()
channel_type
# Out:
# category
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Unknown                   46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
plt.pie(channel_type[:-5],labels=channel_type.index[:-5],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x227857bb790>,
# ...
#  [Text(0.7913278994725502, 0.7640681615643735, 'Entertainment'),
#   Text(-0.6288588799535381, 0.9025167638906115, 'Music'),
#   Text(-1.0942874267217784, -0.11195993800743574, 'People & Blogs'),
#   Text(-0.7488015657530972, -0.8057891877691772, 'Gaming'),
#   Text(-0.2501395025223869, -1.0711816976021635, 'Comedy'),
#   Text(0.15023610103693674, -1.0896922106472173, 'Film & Animation'),
#   Text(0.45869470016758973, -0.9997995659321748, 'Unknown'),
#   Text(0.7253901139667092, -0.8269275558108854, 'Education'),
#   Text(0.9201761968951042, -0.6027236237842868, 'Howto & Style'),
#   Text(1.0257194215693592, -0.3973659122464068, 'News & Politics'),
#   Text(1.0703792656214093, -0.2535512329446905, 'Science & Technology'),
#   Text(1.0896921855919277, -0.15023628276780526, 'Shows'),
#   Text(1.0979849567600826, -0.06655099344532647, 'Sports'),
#   Text(1.0999106635952276, -0.014018991030250443, 'Pets & Animals')],
# ...

# %%
top_sub=['Youtuber','subscribers']
top_sub=dataa.loc[0:9,top_sub]
top_sub['subscribers(MM)']=(dataa['subscribers']/1000000).astype('int')
top_sub
# Out:
#                      Youtuber  subscribers  subscribers(MM)
# 0                    T-Series    245000000              245
# 1              YouTube Movies    170000000              170
# 2                     MrBeast    166000000              166
# 3  Cocomelon - Nursery Rhymes    162000000              162
# 4                   SET India    159000000              159
# 5                       Music    119000000              119
# 6         ýýý Kids Diana Show    112000000              112
# 7                   PewDiePie    111000000              111
# 8                 Like Nastya    106000000              106
# 9               Vlad and Niki     98900000               98

# %%
x=top_sub['Youtuber']
y=top_sub['subscribers(MM)']
# fig = plt.figure(figsize =(10, 6))
ax=plt.barh(x,y,color='#32A645')
for bars in ax.containers:
    ax.bar_label(bars)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\252ha\Desktop\DATA ANALYST\data_analytics\Youtube_statistics.ipynb Cell 21 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/252ha/Desktop/DATA%20ANALYST/data_analytics/Youtube_statistics.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> ax=plt.barh(x,y,color='#32A645')
#       <a href='vscode-notebook-cell:/c%3A/Users/252ha/Desktop/DATA%20ANALYST/data_analytics/Youtube_statistics.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> plt.plot()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/252ha/Desktop/DATA%20ANALYST/data_analytics/Youtube_statistics.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a> for bars in ax.containers:
#       <a href='vscode-notebook-cell:/c%3A/Users/252ha/Desktop/DATA%20ANALYST/data_analytics/Youtube_statistics.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a>     ax.bar_label(bars)
#
# ...

# %%
dataa.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
top_views=['Youtuber','video views']
top_10_views=dataa.sort_values('video views',ascending=True)

top_10_views=dataa.loc[0:9 , top_views]
# top_10_views=top_10_views.sort_values(by='video views',ascending=True)
# top_10_views=pd.DataFrame(top_views)
top_10_views['Views']=(top_10_views['video views']/1000000).astype(int)
print(top_10_views)
# Out:
#                      Youtuber   video views   Views
# 0                    T-Series  228000000000  228000
# 1              YouTube Movies             0       0
# 2                     MrBeast   28368841870   28368
# 3  Cocomelon - Nursery Rhymes  164000000000  164000
# 4                   SET India  148000000000  148000
# 5                       Music             0       0
# 6         ýýý Kids Diana Show   93247040539   93247
# 7                   PewDiePie   29058044447   29058
# 8                 Like Nastya   90479060027   90479
# 9               Vlad and Niki   77180169894   77180

# %%
y=top_10_views['Views']
x=top_10_views['Youtuber']
plt.figure(figsize=(10,10))
plt.barh(x,y,color='#32A645')
plt.plot()
# Out:
# []

# %%
dataa.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
col=['video views','uploads']
rel_views_upload=dataa.loc[0:,col]
rel_views_upload['views']=(rel_views_upload['video views']/100000000).astype('int')
rel_views_upload
# Out:
#       video views  uploads  views
# 0    228000000000    20082   2280
# 1               0        1      0
# 2     28368841870      741    283
# 3    164000000000      966   1640
# 4    148000000000   116536   1480
# ..            ...      ...    ...
# 990    9029609749     1200     90
# 991    1674409945     1500     16
# 992    2214684303     2452     22
# 993     374123483       39      3
# 994    2129773714       62     21
#
# [995 rows x 3 columns]

# %%
y=rel_views_upload['views']
x=rel_views_upload['uploads']
# plt.figure(figsize=(1))
plt.scatter(x,y,color='#32A645')
plt.plot()
# Out:
# []
